# %%
import numpy as np
import pandas as pd

# %%
BDF = pd.read_csv('predictions/2026/detailed_batter_predictions_2026.csv')
PDF = pd.read_csv('predictions/2026/detailed_pitcher_predictions_2026.csv')

# for each of these we can compute average stats by account for the 6x weighting of the projections.

# %%
ADF = pd.concat([BDF, PDF], axis=0, ignore_index=True)

# %%
# take the expert ordering to slot our pitchers in by value

# %%
ADF
# Out:
#            Playerexpert  ABexpert  Rexpert  HRexpert  RBIexpert  SBexpert  \
# 0        Shohei Ohtani      568.0    123.0        46      112.0      24.0
# 1          Aaron Judge      518.0    110.0        46      113.0       9.0
# 2       Bobby Witt Jr.      602.0    101.0        28       92.0      34.0
# 3            Juan Soto      540.0    109.0        37       99.0      20.0
# 4     Ronald Acuna Jr.      540.0    107.0        29       81.0      25.0
# ..                  ...       ...      ...       ...        ...       ...
# 888      Dan Altavilla        NaN      NaN         4        NaN       NaN
# 889       McCade Brown        NaN      NaN         6        NaN       NaN
# 890   Jack Kochanowicz        NaN      NaN         4        NaN       NaN
# 891       Luis Peralta        NaN      NaN         5        NaN       NaN
# 892  Antonio Senzatela        NaN      NaN        11        NaN       NaN
#
#      AVGexpert  OBPexpert  Hexpert  2Bexpert  ...    SO   eSO   ERA  eERA  \
# ...
